# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
from keras.preprocessing import image
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 150,
                                                 class_mode = 'sparse')
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 150,
                                            class_mode = 'sparse')
cnn = tf.keras.models.Sequential()
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
cnn.add(tf.keras.layers.Flatten())
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))
cnn.add(tf.keras.layers.Dense(units=6, activation='softmax'))
cnn.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
cnn.fit(x = training_set, validation_data = test_set, epochs = 15)
# Out:
# Found 9832 images belonging to 6 classes.
# Found 142 images belonging to 6 classes.
# Epoch 1/15
# 66/66 [==============================] - 41s 589ms/step - loss: 1.4026 - accuracy: 0.4144 - val_loss: 2.1446 - val_accuracy: 0.3732
# Epoch 2/15
# 66/66 [==============================] - 38s 579ms/step - loss: 1.1685 - accuracy: 0.5235 - val_loss: 1.9816 - val_accuracy: 0.4155
# Epoch 3/15
# 66/66 [==============================] - 40s 598ms/step - loss: 1.0730 - accuracy: 0.5719 - val_loss: 1.6383 - val_accuracy: 0.4507
# Epoch 4/15
# 66/66 [==============================] - 38s 573ms/step - loss: 1.0220 - accuracy: 0.5948 - val_loss: 1.5307 - val_accuracy: 0.4859
# Epoch 5/15
# 66/66 [==============================] - 37s 571ms/step - loss: 0.9808 - accuracy: 0.6191 - val_loss: 1.3511 - val_accuracy: 0.4718
# Epoch 6/15
# 66/66 [==============================] - 38s 568ms/step - loss: 0.9303 - accuracy: 0.6403 - val_loss: 1.4394 - val_accuracy: 0.5070
# Epoch 7/15
# ...

# %%
import numpy as np
from keras.preprocessing import image



    
test_image = image.load_img('dataset/strawberry.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
predicted_class_index = np.argmax(result)
if predicted_class_index>0.5:
        
# Map the index to the class label using the training_set class indices
    prediction = list(training_set.class_indices.keys())[predicted_class_index]
else:
    prediction = "unidentified"
    
    
if result[0][0] == 1:
    prediction = 'Apple'
elif result[0][1] == 1:
    prediction = 'Banana'
elif result[0][2] == 1:
    prediction = 'Grape'
elif result[0][3] == 1:
    prediction = 'Mango'
elif result[0][4] == 1:
       prediction = 'Strawberry'
else:
    prediction = 'Unidentified'
        
   

#{'Apple': 0, 'Banana': 1, 'Grape': 2, 'Mango': 3, 'Strawberry': 4}
# Out:
# {'Apple': 0, 'Banana': 1, 'Grape': 2, 'Mango': 3, 'Orange': 4, 'Strawberry': 5}
# 1/1 [==============================] - 0s 226ms/step
# Strawberry
# {'Apple': 0, 'Banana': 1, 'Grape': 2, 'Mango': 3, 'Orange': 4, 'Strawberry': 5}
# 1/1 [==============================] - 0s 47ms/step
# Strawberry
# {'Apple': 0, 'Banana': 1, 'Grape': 2, 'Mango': 3, 'Orange': 4, 'Strawberry': 5}
# 1/1 [==============================] - 0s 51ms/step
# Strawberry
# {'Apple': 0, 'Banana': 1, 'Grape': 2, 'Mango': 3, 'Orange': 4, 'Strawberry': 5}
# 1/1 [==============================] - 0s 48ms/step
# Strawberry
# {'Apple': 0, 'Banana': 1, 'Grape': 2, 'Mango': 3, 'Orange': 4, 'Strawberry': 5}
# 1/1 [==============================] - 0s 46ms/step
# Strawberry
# {'Apple': 0, 'Banana': 1, 'Grape': 2, 'Mango': 3, 'Orange': 4, 'Strawberry': 5}
# 1/1 [==============================] - 0s 43ms/step
# Strawberry
# {'Apple': 0, 'Banana': 1, 'Grape': 2, 'Mango': 3, 'Orange': 4, 'Strawberry': 5}
# ...
